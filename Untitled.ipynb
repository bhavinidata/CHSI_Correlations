# %%
import pandas as pd
import numpy as np

# %%
demographic_df = pd.read_csv("CHSICorrelations/data/CHSI_dataset/DEMOGRAPHICS.csv")

# %%
demographic_df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  \
# 0              AL                29
# 1              AL                16
# 2              AL                51
# 3              AL                42
# 4              AL                28
#
#                           Strata_Determining_Factors  Number_Counties  \
# 0     frontier status, population size, poverty, age               37
# 1     frontier status, population size, poverty, age               27
# 2  frontier status, population size, poverty, age...               33
# ...

# %%
riskfactor_df = pd.read_csv("CHSICorrelations/data/CHSI_dataset/RISKFACTORSANDACCESSTOCARE.csv")

# %%
riskfactor_df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  No_Exercise  CI_Min_No_Exercise  \
# 0              AL                29         27.8                20.7
# 1              AL                16         27.2                23.2
# 2              AL                51      -1111.1             -1111.1
# 3              AL                42      -1111.1             -1111.1
# 4              AL                28         33.5                26.3
#
#    CI_Max_No_Exercise  Few_Fruit_Veg  ...  Diabetes  CI_Min_Diabetes  \
# ...

# %%
demo_riskfact_df = pd.merge(demographic_df, riskfactor_df, how ="inner", on = ["State_FIPS_Code", "County_FIPS_Code"])

# %%
demo_riskfact_df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name_x CHSI_State_Name_x  \
# 0                1                 1            Autauga           Alabama
# 1                1                 3            Baldwin           Alabama
# 2                1                 5            Barbour           Alabama
# 3                1                 7               Bibb           Alabama
# 4                1                 9             Blount           Alabama
#
#   CHSI_State_Abbr_x  Strata_ID_Number_x  \
# 0                AL                  29
# 1                AL                  16
# 2                AL                  51
# 3                AL                  42
# 4                AL                  28
#
#                           Strata_Determining_Factors  Number_Counties  \
# 0     frontier status, population size, poverty, age               37
# 1     frontier status, population size, poverty, age               27
# ...

# %%
riskfactor_df = riskfactor_df.melt(id_vars=["CHSI_State_Name", "CHSI_State_Abbr", "CHSI_County_Name", "Number_Counties",
                                           ], 
        var_name="Date", 
        value_name="Value")
